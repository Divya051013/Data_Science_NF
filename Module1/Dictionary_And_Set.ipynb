# %% [markdown]
# <a href="https://colab.research.google.com/github/Divya051013/Data_Science_NF/blob/main/Module1/Dictionary_And_Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
keys = ["a", "b", "c"]
values = [1, 2, 3]

dictionary = dict(zip(keys, values))

print("Dictionary:", dictionary)
# Out:
# Dictionary: {'a': 1, 'b': 2, 'c': 3}

# %%
dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}

merged_dict = {**dict1, **dict2}

print("Merged Dictionary:", merged_dict)
# Out:
# Merged Dictionary: {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
my_dict = {"a": 3, "b": 1, "c": 2}

sorted_dict = dict(sorted(my_dict.items(), key=lambda item: item[1]))

print("Sorted Dictionary:", sorted_dict)
# Out:
# Sorted Dictionary: {'b': 1, 'c': 2, 'a': 3}

# %%
set1 = {1, 2}
set2 = {1, 2, 3, 4}

print("Is subset:", set1.issubset(set2))
# Out:
# Is subset: True

# %%
list1 = [1, 2, 3]
list2 = [3, 4, 5]

common = set(list1) & set(list2)

if common:
    print("They have common elements:", common)
else:
    print("No common elements")
# Out:
# They have common elements: {3}
